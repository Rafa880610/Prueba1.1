# %%
from google.colab import drive
import pandas as pd
import numpy as np
import os

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Mod3Clase1/'
list_files = os.listdir(path)
list_files
# Out:
# ['Reto_03_Student_Performance.csv',
#  'Reto_02_Salary_Professions.csv',
#  'Reto_01_Laptops_Dataset.csv',
#  'M03_S01_datasets_descrip.pdf',
#  'Ejemplo_01_Titanic_Dataset.csv']

# %%
df = pd.read_csv(os.path.join(path, "Ejemplo_01_Titanic_Dataset.csv"))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# Media

# %%
promedio_edad = df["Age"].mean()
promedio_edad
# Out:
# 30.272590361445783

# %% [markdown]
# Mediana

# %%
mediana_edad = df["Age"].median()
mediana_edad
# Out:
# 27.0

# %% [markdown]
# Moda

# %%
moda_edad = df ["Age"].mode()
moda_edad
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
df = pd.read_csv(os.path.join(path, "Reto_01_Laptops_Dataset.csv"))
df
# Out:
#        brand                             name     price  spec_score  \
# 0         hp        Victus 15-fb0157AX Gaming   49800.0        70.0
# 1     xiaomi          Redmi G Pro 2024 Gaming  102990.0        78.0
# 2      tecno                      Megabook T1   23990.0        56.0
# 3    samsung              Galaxy Book2 Pro 13   62990.0        60.0
# 4      apple         MacBook Air 2020 MGND3HN   79990.0        43.0
# ..       ...                              ...       ...         ...
# 992     dell         Vostro 3420 D552317WIN9B   51199.0        55.0
# 993       hp          Spectre x360 16-f2005TX  185990.0        84.0
# 994       hp  Spectre x360 2023 13.5-ef2033TU  139990.0        68.0
# 995   huawei                MateBook D14 2023   58999.0        62.0
# 996   huawei                MateBook D16 2023   84999.0        59.0
#
#      user_votes  user_rating           os  utility: Business  \
# 0          97.0          4.3   windows 11                  0
# ...

# %%
promedio_precio = df["price"].mean()
promedio_precio
# Out:
# 84889.24974924774

# %%
mediana_precio = df["price"].median()
mediana_precio
# Out:
# 64690.0

# %%
moda_precio = df ["price"].mode()
moda_precio
# Out:
# 0    59990.0
# Name: price, dtype: float64

# %%
df["price"].unique()
# Out:
# array([ 49800., 102990.,  23990.,  62990.,  79990.,  26780.,  35990.,
#         54990.,  52990.,  99900.,  32990.,  81490.,  24990.,  33990.,
#         26749.,  58990.,  74990.,  39990.,  43990.,  56490.,  59990.,
#        114900.,  99990.,  49990.,  42990.,  55390.,  89999.,  84990.,
#         33790.,  27990.,  44990.,  65990.,  77990., 120900.,  19979.,
#         89990.,  25680.,  37990.,  69999.,  46990.,  72990.,   8000.,
#        154900., 134225., 146990.,  63490., 191668.,  75990., 329990.,
#        135999.,  51990.,  36990.,  34880., 137990., 599990., 149990.,
#        199990.,  84700., 399900., 186899.,  24790.,  69990.,  41990.,
#         35900.,  64690.,  71990.,  35091.,  48490.,  53990.,  53999.,
#         19990.,  35790.,  73990.,  12990.,  18990.,  76990.,  54790.,
#         36890.,  86990.,  36280.,  31990.,  64990.,  57990.,  70490.,
#         89900.,  52999., 112990.,  68990.,  68490., 104990.,  94990.,
# ...

# %%
df ["price"].mode()
# Out:
# 0    59990.0
# Name: price, dtype: float64

# %%
df ["price"].max()
# Out:
# 599990.0

# %% [markdown]
# Varianza

# %%
varianza_fare = df["Fare"].var()
varianza_fare
# Out:
# 3125.6570743195775

# %%
desviacion_estandar_fare = df["Fare"].std()
desviacion_estandar_fare
# Out:
# 55.90757617997383

# %%
df["Fare"].mean()
# Out:
# 35.627188489208635

# %% [markdown]
# Rango

# %%
edad_max = df["Age"].max()
edad_min = df["Age"].min()

# %%
Edad_rango = edad_max - edad_min

# %%
from scipy import stats
